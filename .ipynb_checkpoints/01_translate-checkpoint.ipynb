# %%
print('Traducere text')
# Out:
# Traducere text

# %%
#!pip install goslate
import goslate
# Out:
# Collecting goslate
#   Downloading https://files.pythonhosted.org/packages/39/0b/50af938a1c3d4f4c595b6a22d37af11ebe666246b05a1a97573e8c8944e5/goslate-1.5.1.tar.gz
# Collecting futures (from goslate)
#   Downloading https://files.pythonhosted.org/packages/05/80/f41cca0ea1ff69bce7e7a7d76182b47bb4e1a494380a532af3e8ee70b9ec/futures-3.1.1-py3-none-any.whl
# Building wheels for collected packages: goslate
#   Building wheel for goslate (setup.py): started
#   Building wheel for goslate (setup.py): finished with status 'done'
#   Created wheel for goslate: filename=goslate-1.5.1-cp37-none-any.whl size=11555 sha256=e22e7e944f411113ef75f4e2e99423ff200152f79f28e6192010eed9737cdb6f
#   Stored in directory: C:\Users\mhcrn\AppData\Local\pip\Cache\wheels\4f\7f\28\6f52271012a7649b54b1a7adaae329b4246bbbf9d1e4f6e51a
# Successfully built goslate
# Installing collected packages: futures, goslate
# Successfully installed futures-3.1.1 goslate-1.5.1

# %%
gs =goslate.Goslate()
print(gs.translate('hello world', 'de'))
# Out:
# Hallo Welt

# %%
print (gs.translate('Salut', 'de'))
# Out:
# Gesundheit

# %%
print (gs.translate('stau', 'de'))
# Out:
# Aufenthalt

# %%
print (gs.translate('vedea', 'de'))
# Out:
# sehen

# %%
print (gs.translate('lua', 'de'))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-4e648d95d1c4> in <module>
# ----> 1 print (gs.translate('lua', 'de'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in translate(self, text, target_language, source_language)
#     407             if isinstance(text, unicode):
#     408                 text = text.encode('utf-8')
# --> 409             return _unwrapper_single_element(self._translate_single_text(text, target_language, source_language))
#     410
#     411         JOINT = u'\u26ff'
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _translate_single_text(self, text, target_language, source_lauguage)
#     332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
# --> 334         results = list(self._execute(make_task(i) for i in split_text(text)))
#     335         return tuple(''.join(i[n] for i in results) for n in range(len(self._writing)))
#     336
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _execute(self, tasks)
#     201         if not first_tasks[-1] or not self._executor:
#     202             for each in tasks:
# --> 203                 yield each()
#     204         else:
#     205             exception = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in <lambda>()
#     330
#     331         def make_task(text):
# --> 332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
#     334         results = list(self._execute(make_task(i) for i in split_text(text)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _basic_translate(self, text, target_language, source_language)
#     249             url += '&dt=rm'
#     250
# --> 251         response_content = self._open_url(url)
#     252         raw_data = json.loads(_empty_comma.subn('', response_content)[0].replace(u'\xA0', u' ').replace('[,', '[1,'))
#     253         data = {'src': raw_data[-1][0][0]}
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     189                     print(threading.currentThread(), e)
#     190                 if 'Connection reset by peer' not in str(e):
# --> 191                     raise e
#     192                 exception = e
#     193                 time.sleep(0.0001)
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     179         for i in range(self._RETRY_TIMES):
#     180             try:
# --> 181                 response = self._opener.open(request, timeout=self._TIMEOUT)
#     182                 response_content = response.read().decode('utf-8')
#     183                 if self._DEBUG:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
print (gs.translate('camera', 'de', 'ro'))
gs.translate?
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-18-92e25703c698> in <module>
# ----> 1 print (gs.translate('camera', 'de', 'ro'))
#       2 get_ipython().run_line_magic('pinfo', 'gs.translate')
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in translate(self, text, target_language, source_language)
#     407             if isinstance(text, unicode):
#     408                 text = text.encode('utf-8')
# --> 409             return _unwrapper_single_element(self._translate_single_text(text, target_language, source_language))
#     410
#     411         JOINT = u'\u26ff'
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _translate_single_text(self, text, target_language, source_lauguage)
#     332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
# --> 334         results = list(self._execute(make_task(i) for i in split_text(text)))
#     335         return tuple(''.join(i[n] for i in results) for n in range(len(self._writing)))
#     336
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _execute(self, tasks)
#     201         if not first_tasks[-1] or not self._executor:
#     202             for each in tasks:
# --> 203                 yield each()
#     204         else:
#     205             exception = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in <lambda>()
#     330
#     331         def make_task(text):
# --> 332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
#     334         results = list(self._execute(make_task(i) for i in split_text(text)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _basic_translate(self, text, target_language, source_language)
#     249             url += '&dt=rm'
#     250
# --> 251         response_content = self._open_url(url)
#     252         raw_data = json.loads(_empty_comma.subn('', response_content)[0].replace(u'\xA0', u' ').replace('[,', '[1,'))
#     253         data = {'src': raw_data[-1][0][0]}
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     189                     print(threading.currentThread(), e)
#     190                 if 'Connection reset by peer' not in str(e):
# --> 191                     raise e
#     192                 exception = e
#     193                 time.sleep(0.0001)
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     179         for i in range(self._RETRY_TIMES):
#     180             try:
# --> 181                 response = self._opener.open(request, timeout=self._TIMEOUT)
#     182                 response_content = response.read().decode('utf-8')
#     183                 if self._DEBUG:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests

# %%
gs.detect('Salut')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-22-431157b99ada> in <module>
# ----> 1 gs.detect('Salut')
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in detect(self, text)
#     482         if _is_sequence(text):
#     483             return self._execute(functools.partial(self._detect_language, i) for i in text)
# --> 484         return self._detect_language(text)
#     485
#     486
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _detect_language(self, text)
#     446         if _is_bytes(text):
#     447             text = text.decode('utf-8')
# --> 448         return self._basic_translate(text[:50].encode('utf-8'), 'en', 'auto')[1]
#     449
#     450
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _basic_translate(self, text, target_language, source_language)
#     249             url += '&dt=rm'
#     250
# --> 251         response_content = self._open_url(url)
#     252         raw_data = json.loads(_empty_comma.subn('', response_content)[0].replace(u'\xA0', u' ').replace('[,', '[1,'))
#     253         data = {'src': raw_data[-1][0][0]}
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     189                     print(threading.currentThread(), e)
#     190                 if 'Connection reset by peer' not in str(e):
# --> 191                     raise e
#     192                 exception = e
#     193                 time.sleep(0.0001)
#
# C:\ProgramData\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     179         for i in range(self._RETRY_TIMES):
#     180             try:
# --> 181                 response = self._opener.open(request, timeout=self._TIMEOUT)
#     182                 response_content = response.read().decode('utf-8')
#     183                 if self._DEBUG:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 429: Too Many Requests
